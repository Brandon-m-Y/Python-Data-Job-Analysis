# %%
import pandas as pd
import ast
import numpy as np
import matplotlib.pyplot as plt
from datasets import load_dataset
import seaborn as sns

# %%
# Loading Dataset
dataset = load_dataset('lukebarousse/data_jobs')
df = dataset['train'].to_pandas()

# Data Cleanup
df['job_posted_date'] = pd.to_datetime(df['job_posted_date'])
df['job_skills'] = df['job_skills'].apply(lambda x: ast.literal_eval(x) if pd.notna(x) else x)

# %%
# Fillter for US jobs and drop na values
df_US = df[(df['job_country'] == "United States")].dropna(subset=['salary_year_avg'])

# %%
# Get the top six job titles by value count
job_titles = df_US['job_title_short'].value_counts().index[:6].tolist()
job_titles
# Out:
# ['Data Scientist',
#  'Data Analyst',
#  'Data Engineer',
#  'Senior Data Scientist',
#  'Senior Data Engineer',
#  'Senior Data Analyst']

# %%
# Filter to only top six values from the data frame
df_US_top6 = df_US[df_US['job_title_short'].isin(job_titles)]

df_US_top6.head()
# Out:
#     job_title_short                                          job_title  \
# 92    Data Engineer            Remote - Data Engineer - Permanent - W2
# 100  Data Scientist            Data Scientist, Risk Data Mining - USDS
# 109    Data Analyst              Senior Supply Chain Analytics Analyst
# 116  Data Scientist                                     Data Scientist
# 146   Data Engineer  Data Engineer Graduate (Real Time Communicatio...
#
#           job_location       job_via job_schedule_type  job_work_from_home  \
# 92            Anywhere  via LinkedIn         Full-time                True
# 100  Mountain View, CA  via LinkedIn         Full-time               False
# 109           Anywhere    via Get.It         Full-time                True
# 116           Anywhere  via LinkedIn         Full-time                True
# 146        Seattle, WA  via LinkedIn         Full-time               False
#
#                search_location     job_posted_date  job_no_degree_mention  \
# ...

# %%
# Order job titles by their median salary and get their index
job_order = df_US_top6.groupby('job_title_short')['salary_year_avg'].median().sort_values(ascending=False).index
job_order
# Out:
# Index(['Senior Data Scientist', 'Senior Data Engineer', 'Data Scientist',
#        'Data Engineer', 'Senior Data Analyst', 'Data Analyst'],
#       dtype='object', name='job_title_short')

# %%
# Create boxplots for salary distributions
sns.boxplot(data=df_US_top6, x='salary_year_avg', 
            y='job_title_short', 
            order=job_order) 

sns.set_theme(style='ticks')

plt.title('Salary Distribution in teh US ($USD)')
plt.ylabel('')
plt.xlabel('Yearly Salary')
ax = plt.gca()
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, pos: f'${int(x/1000)}k'))
plt.xlim(0, 600000)
plt.show()

# %%
# Filter for Data Analysts in the US
df_DA_US = df[(df['job_title_short'] == 'Data Analyst') & (df['job_country'] == 'United States')].copy()

# Drop na values from salary
df_DA_US = df_DA_US.dropna(subset=['salary_year_avg'])

# %%
# Explode skills lists from job skills columns
df_DA_US = df_DA_US.explode('job_skills')

# Show salary_year_avg and job_skills
df_DA_US[['salary_year_avg', 'job_skills']].head(5)
# Out:
#      salary_year_avg job_skills
# 109          89000.0     python
# 109          89000.0          r
# 109          89000.0    alteryx
# 109          89000.0    tableau
# 180          90250.0      excel

# %%
# Find top paying skills by median grouping by skills and agg by count()
df_DA_top_pay = df_DA_US.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='median',ascending=False)

df_DA_top_pay =df_DA_top_pay.head(10)

df_DA_top_pay
# Out:
#               count    median
# job_skills
# dplyr             2  196250.0
# bitbucket         3  189000.0
# gitlab            3  186000.0
# solidity          1  179000.0
# hugging face      1  175000.0
# couchbase         1  160515.0
# ansible           1  159640.0
# mxnet             2  149000.0
# cassandra         6  148250.0
# vmware            1  147500.0

# %%
# Find top paying skills by count grouping by skills and agg by count()
df_DA_skills = df_DA_US.groupby('job_skills')['salary_year_avg'].agg(['count', 'median']).sort_values(by='count',ascending=False)

# Sort top top ten highest count skills by their median salary
df_DA_skills = df_DA_skills.head(10).sort_values(by='median', ascending=False)
df_DA_skills
# Out:
#             count    median
# job_skills
# python       1431  97500.00
# tableau      1364  92875.00
# r             893  92500.00
# sql server    286  92500.00
# sql          2508  91000.00
# sas           926  90000.00
# power bi      838  90000.00
# powerpoint    462  85000.00
# excel        1808  84392.00
# word          461  81194.75

# %%
# Barplot of top skills by their median salary

fig, ax = plt.subplots(2, 1)

# df_DA_top_pay.plot(kind='barh', y='median', ax=ax[0], legend=False)

sns.barplot(data=df_DA_top_pay, x='median', y=df_DA_top_pay.index, ax=ax[0], hue='median', palette='dark:b_r')

# ax[0].invert_yaxis()
ax[0].set_title("Top 10 Highest Paid Skills for Data Analysts")
ax[0].set_ylabel('')
ax[0].set_xlabel('')
ax[0].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K' ))
ax[0].legend().remove()

# df_DA_skills.plot(kind='barh', y='median', ax=ax[1], legend=False)

sns.barplot(data=df_DA_skills, x='median', y=df_DA_skills.index, ax=ax[1], hue='median',  palette='light:b')

# ax[1].invert_yaxis()
ax[1].set_title('Top 10 Most In-Demand Skills for Data Analysts')
ax[1].set_ylabel('')
ax[1].set_xlabel('Median Salary ($USD)')
ax[1].set_xlim(ax[0].get_xlim())
ax[1].xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'${int(x/1000)}K' ))
ax[1].legend().remove()
fig.tight_layout()
plt.show()
