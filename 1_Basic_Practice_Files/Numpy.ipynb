# %%
import random

salary_list = [random.randint(50000, 100000) for i in range(1000000)]

# %%
import statistics

# %%
# %%timeit

statistics.mean(salary_list)
# Out:
# 296 ms ± 3.49 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import numpy as np

# %%
# %%timeit

np.mean(salary_list)
# Out:
# 46.1 ms ± 248 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
np.array([1,2,3,4,5,6,7])
# Out:
# array([1, 2, 3, 4, 5, 6, 7])

# %%
my_array = np.array([1,2,3,4,5,6,7])

# %%
my_array.mean()
# Out:
# 4.0
