# %%
skills = ('python', 'sql', 'R')

# %%
skills
# Out:
# ('python', 'sql', 'R')

# %%
skills[0]
# Out:
# 'python'

# %%
skills[0:2]
# Out:
# ('python', 'sql')

# %%
skills = ('python', 'sql', 'R', 'java')
print(id(skills))
new_skills = ('Excel', 'Tableau', 'git')

skills + new_skills
# Out:
# 2632022250960
# ('python', 'sql', 'R', 'java', 'Excel', 'Tableau', 'git')

# %%
skills += new_skills

skills
# Out:
# ('python', 'sql', 'R', 'java', 'Excel', 'Tableau', 'git')

# %%
id(skills)
# Out:
# 2632022251840
