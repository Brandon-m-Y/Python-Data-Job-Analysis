# %%
import pandas as pd
from datetime import datetime

# %%
job_listings = [
    {
        "title": "Data Analyst",
        "company": "TechNova",
        "location": "Remote",
        "salary_usd": 85000,
        "posted_at": "2025-12-20"
    },
    {
        "title": "Machine Learning Engineer",
        "company": "Insight AI",
        "location": "San Francisco, CA",
        "salary_usd": 135000,
        "posted_at": "2025-12-18"
    },
    {
        "title": "Business Intelligence Analyst",
        "company": "RetailCore",
        "location": "Chicago, IL",
        "salary_usd": 92000,
        "posted_at": "2025-12-22"
    },
    {
        "title": "Junior Data Scientist",
        "company": "HealthMetrics",
        "location": "Boston, MA",
        "salary_usd": 98000,
        "posted_at": "2025-12-21"
    },
    {
        "title": "Analytics Engineer",
        "company": "FinEdge",
        "location": "New York, NY",
        "salary_usd": 120000,
        "posted_at": "2025-12-23"
    }
]

# %%
datetime.now()
# Out:
# datetime.datetime(2025, 12, 26, 14, 51, 34, 231112)

# %%
test_date = job_listings[1]['posted_at']

# %%
datetime.strptime(test_date, '%Y-%m-%d')
# Out:
# datetime.datetime(2025, 12, 18, 0, 0)

# %%
print(datetime.strptime(test_date, '%Y-%m-%d'))
# Out:
# 2025-12-18 00:00:00

# %%
for i in job_listings:
    test_date = i['posted_at']
    print(datetime.strptime(test_date, '%Y-%m-%d'))
# Out:
# 2025-12-20 00:00:00
# 2025-12-18 00:00:00
# 2025-12-22 00:00:00
# 2025-12-21 00:00:00
# 2025-12-23 00:00:00

# %%
for job in job_listings:
    job['posted_at'] = datetime.strptime(job['posted_at'], '%Y-%m-%d')

# %%
job_listings
# Out:
# [{'title': 'Data Analyst',
#   'company': 'TechNova',
#   'location': 'Remote',
#   'salary_usd': 85000,
#   'posted_at': datetime.datetime(2025, 12, 20, 0, 0)},
#  {'title': 'Machine Learning Engineer',
#   'company': 'Insight AI',
#   'location': 'San Francisco, CA',
#   'salary_usd': 135000,
#   'posted_at': datetime.datetime(2025, 12, 18, 0, 0)},
#  {'title': 'Business Intelligence Analyst',
#   'company': 'RetailCore',
#   'location': 'Chicago, IL',
#   'salary_usd': 92000,
#   'posted_at': datetime.datetime(2025, 12, 22, 0, 0)},
#  {'title': 'Junior Data Scientist',
#   'company': 'HealthMetrics',
#   'location': 'Boston, MA',
#   'salary_usd': 98000,
#   'posted_at': datetime.datetime(2025, 12, 21, 0, 0)},
#  {'title': 'Analytics Engineer',
#   'company': 'FinEdge',
#   'location': 'New York, NY',
#   'salary_usd': 120000,
#   'posted_at': datetime.datetime(2025, 12, 23, 0, 0)}]

# %%
import ast

for job in job_listings:
    job['posted_at'] = datetime.strptime(job['posted_at'], '%Y-%m-%d')
