# %%
job_skills = {'sql', 'tableau', 'python', 'stats'}

# %%
job_skills
# Out:
# {'python', 'sql', 'stats', 'tableau'}

# %%
job_skills.add('java')

# %%
job_skills
# Out:
# {'java', 'python', 'sql', 'stats', 'tableau'}

# %%
job_skills.pop()
# Out:
# 'java'

# %%
job_skills
# Out:
# {'python', 'sql', 'stats', 'tableau'}

# %%
job_skills.remove('sql')

# %%
job_skills
# Out:
# {'python', 'stats', 'tableau'}
